# %%
import logging

## Configure logging settings
logging.basicConfig(
    level = logging. DEBUG,
    format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt = "%Y-%m-%d %H:%M:%S" 
)

## Create a loger for module1

logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)

## logger for modulee
logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)

# %%
## Log message with diff loggers

logger1.debug('This is a debug message for Module1')
logger2.warning('This is a warning message for Module2')
logger2.error('This is an error')
# Out:
# 2026-01-20 10:29:12 - module1 - DEBUG - This is a debug message for Module1
# 2026-01-20 10:29:12 - module2 - WARNING - This is a warning message for Module2
# 2026-01-20 10:29:12 - module2 - ERROR - This is an error
