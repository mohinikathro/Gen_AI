# %% [markdown]
# #### Building a simple LLM Application using LCEL (LangChain Expression Language)

# %%
### Open Source models: Llama3, Gemma2, Mistral (using these models using Groq)

# %%
import os
from dotenv import load_dotenv
load_dotenv()

import openai
openai.api_keys = os.getenv('OPENAI_API_KEY')

groq_api_key = os.getenv('GROQ_API_KEY')

# %%
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI

model = ChatGroq(model = 'Gemma2-9b-It', groq_api_key = groq_api_key)
model
# Out:
# ChatGroq(profile={}, client=<groq.resources.chat.completions.Completions object at 0x15a520e10>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x15a521810>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))
