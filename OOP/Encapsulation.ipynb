# %%
### Encapsulation 
## Public, protected and private variables or access modifiers

class Person:
    def __init__(self, name, age):
        self.name = name # public variable
        self.age = age # public variable

def get_name(person):
    return person.name

person = Person("Alex", 34)
print(person.name)

get_name(person)
# Out:
# Alex
# 'Alex'

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person:
    def __init__(self, name, age, gender):
        self.__name = name # private variable
        self.__age = age # private variable
        self.gender = gender

def get_name(person):
    return person.__name

person2 = Person('Alex', 34, 'Male')
get_name(person2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 11
#       8     return person.__name
#      10 person2 = Person('Alex', 34, 'Male')
# ---> 11 get_name(person2)
#
# Cell In[11], line 8, in get_name(person)
#       7 def get_name(person):
# ----> 8     return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
person1 = Person('Alex', 34, 'Male')
dir(person1)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
class Person:
    def __init__(self, name, age, gender):
        self._name = name # protected variable
        self._age = age # protected variable
        self.gender = gender
class Emp(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

emp1 = Emp('Sue', 28, "Female")
print(emp1._name)
# Out:
# Sue

# %%
### Encapsulation with Getter and Setter Method

class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    ## Getter method for name
    def get_name(self):
        return self.__name
    
    ## Setter method for name
    def set_name(self, name):
        self.__name = name

    def get_age(self):
        return self.__age
    
    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print('Age can not be negative')


person3 = Person('Sue', 28)


print(person3.get_name())
print(person3.get_age())

person3.set_age(32)
print(person3.get_age())

person3.set_age(-5)
# Out:
# Sue
# 28
# 32
# Age can not be negative
