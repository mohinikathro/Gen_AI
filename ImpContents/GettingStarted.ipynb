# %% [markdown]
# #### In this will see how to:
# - Get setup with LangChain, LangSmith, and LangServe
# - Use the most basic and common components of LangChain: prompt, templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv

load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# Used for LangSmith Tracking
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')

os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_PROJECT'] = os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-4o')
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x143d39310> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x143ebd1d0> root_client=<openai.OpenAI object at 0x143d3bc50> root_async_client=<openai.AsyncOpenAI object at 0x143ebead0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
# Input and get response from LLM

result = llm.invoke('What is generative AI?')

# %%
print(result)
# Out:
# content='Generative AI refers to a subset of artificial intelligence that is designed to generate new content, ranging from text and images to music and video, often mimicking human creativity. It typically involves the use of sophisticated algorithms, such as neural networks and deep learning models, to produce outputs that are not explicitly programmed by humans.\n\nSome of the most common generative AI models include:\n\n1. **Generative Adversarial Networks (GANs):** These involve two neural networks, a generator and a discriminator, that work against each other. The generator creates new data instances, while the discriminator evaluates them. The goal is for the generator to produce increasingly convincing data that can fool the discriminator.\n\n2. **Variational Autoencoders (VAEs):** These models encode input data into a compressed representation and then decode it to reconstruct the data, learning to generate variations of the data in the process.\n\n3. **Transformers and Large Language Models:** Models like GPT (Generative Pre-trained Transformer) are used for generating human-like text by predicting the next word in a sentence based on the context of the words preceding it. They are extensively used in natural language processing tasks.\n\nGenerative AI has numerous applications, including but not limited to:\n\n- Text generation (e.g., writing articles, scripts, or chat responses)\n- Image generation (e.g., creating artwork, enhancing photos)\n- Audio and music synthesis\n- Creating video content\n- Developing virtual environments or simulations\n\nGenerative AI is celebrated for its potential to aid in creative processes, automate content creation, and even assist in fields like healthcare and engineering by generating design prototypes or suggesting solutions. However, it also raises ethical concerns, notably regarding the creation of deepfakes, intellectual property rights, and the potential for misuse of generated content.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 358, 'prompt_tokens': 13, 'total_tokens': 371, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D2ieL9mW3cnYa4bB4hVq8CBqgHWM0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c00d7-b06e-70a2-b12d-e7146b91fd22-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 358, 'total_tokens': 371, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ('system', 'You are an expert AI Engineer. Provide me answers based on the question'),
        ('user', '{input}')
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
# Chain
chain = prompt | llm
response = chain.invoke({"input: 'Can you tell me about LangSmith?"})
print(response)
# Out:
# content='LangSmith is a platform designed to enhance the application development experience with Language Learning Models (LLMs). It provides a suite of tools and functionalities tailored to test, evaluate, and improve LLM applications effectively. LangSmith allows developers to track the performance of their models, debug issues, and optimize for better results by offering features such as detailed insights, testing environments, and fine-tuning capabilities. The goal of LangSmith is to streamline the process of integrating and maintaining LLMs in applications, making it easier for developers to harness the power of these models efficiently.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 38, 'total_tokens': 150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D2irbOTwnAvywRrOiZjavTtmPJISz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c00e4-3862-76b0-a7a6-4bdf14d5cee7-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 38, 'output_tokens': 112, 'total_tokens': 150, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
# stroutput Parser

from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()
chain = prompt | llm | output_parser

response = chain.invoke({"input: 'Can you tell me about LangSmith?"})
print(response)
# Out:
# LangSmith is a notable software tool designed to enhance the development and deployment of applications that utilize natural language processing or conversational AI functionalities. Its key offerings typically include tools for tracing, debugging, and evaluating language model applications, which are vital for developers aiming to optimize performance and accuracy. Integrated within this framework, LangSmith often provides features for monitoring interactions, logging, and analyzing communication patterns, enabling developers to gain insights into application performance and user engagement. The platform is particularly useful for those working with advanced language models like GPT-3 and subsequent versions, effectively facilitating the iterative development process by providing necessary infrastructure for both pre-deployment testing and post-deployment maintenance.
